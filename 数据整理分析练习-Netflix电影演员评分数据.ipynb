# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character：角色姓名。
# - role：演职员类型，演员或导演。

# %% [markdown]
# # 读取数据

# %%
import pandas as pd

# %%
titles = pd.read_csv("titles.csv")
credits = pd.read_csv("credits.csv")
credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %% [markdown]
# # 评估数据及清洗数据

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# ”character“一项有缺失值，但并不影响对评分的分析

# %%
credits.sample(10)
# Out:
#        person_id         id               name  \
# 44920      18135   tm368699     Phillip DeVona
# 76849    1181245  tm1029279      Lauren Daigle
# 55995      88185   tm897170  Stéphane Caillard
# 66285     103556   ts286731       Rie Murakawa
# 28109    1681389   tm315344         John Krpan
# 21974     108467   tm196125      A.J. Ackleson
# 56766    2429724   tm496648     Nicolas Gerout
# 34795     108073   ts131579   Tibo Vandenborre
# 5458       44346    ts30311         Avan Jogia
# 53752     648215   tm454824      Arkadiy Koval
#
#                             character   role
# 44920     Calvin Claytor (uncredited)  ACTOR
# 76849                             NaN  ACTOR
# 55995                    Chloé Diallo  ACTOR
# 66285            Najimi Osana (voice)  ACTOR
# 28109                       LA Player  ACTOR
# 21974              Hipster Turkey Man  ACTOR
# 56766         Fred, Samia's boyfriend  ACTOR
# 34795                      De Spanjol  ACTOR
# 5458                      Beck Oliver  ACTOR
# 53752  Nikolai Nikolaevich's governor  ACTOR

# %% [markdown]
# 无结构性问题，下面看是否有内容性问题

# %%
credits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 无重复性数据

# %%
credits.value_counts(subset = ["role"])
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %% [markdown]
# 无不一致数据

# %% [markdown]
# 由于是演员表，无需评估无效或错误数据

# %%
cleaned_credits = credits.copy()

# %% [markdown]
# 对person_id一项，转换成字符串

# %%
cleaned_credits["person_id"] = cleaned_credits["person_id"].astype("str")
cleaned_credits["person_id"]
# Out:
# 0           3748
# 1          14658
# 2           7064
# 3           3739
# 4          48933
#           ...
# 77796     736339
# 77797     399499
# 77798     373198
# 77799     378132
# 77800    1950416
# Name: person_id, Length: 77801, dtype: object

# %% [markdown]
# 下面看titles一表

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 685.7+ KB

# %%
titles.sample(10)
# Out:
#             id               title   type  \
# 2976  tm350945             Posesif  MOVIE
# 1425  tm240895     Strange Weather  MOVIE
# 2907  tm325650      King of Peking  MOVIE
# 3177  tm441232       Someone Great  MOVIE
# 3274  tm411750  Doom: Annihilation  MOVIE
# 5308  tm879685  The Perfect Family  MOVIE
# 5541  tm810657              Uppena  MOVIE
# 857    ts14583     BoJack Horseman   SHOW
# 2944  tm350116        B. A. Pass 2  MOVIE
# 5548  tm855340           Thalaivii  MOVIE
#
#                                             description  release_year  \
# 2976  A student diver risks her scholastic future an...          2017
# 1425  Years after her son's suicide, a woman longs t...          2016
# 2907  When home entertainment enters the market in 9...          2017
# 3177  An aspiring music journalist lands her dream j...          2019
# 3274  A group of UAC Marines responds to a distress ...          2019
# 5308  Lucia's achievement of a perfect family is thr...          2021
# 5541  Aasi has been in love with Bebamma since their...          2021
# 857   Meet the most beloved sitcom horse of the 90s ...          2014
# 2944  B. A. Pass 2 is the story of a young girl, who...          2017
# 5548  The biopic charts the life of actor-turned-chi...          2021
#
#      age_certification  runtime                                     genres  \
# 2976               NaN      102             ['drama', 'comedy', 'romance']
# 1425                 R       95                                  ['drama']
# 2907               NaN       88                        ['drama', 'comedy']
# 3177                 R       92                      ['romance', 'comedy']
# 3274                 R       96  ['action', 'scifi', 'thriller', 'horror']
# 5308               NaN      110                                 ['comedy']
# 5541               NaN      147                                  ['drama']
# 857              TV-MA       26           ['comedy', 'drama', 'animation']
# 2944               NaN      136                                  ['drama']
# 5548                 G      153                                  ['drama']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 2976               ['ID']      NaN   tt7541708         7.4       920.0
# 1425               ['US']      NaN   tt5205210         6.0      1499.0
# 2907   ['AU', 'US', 'CN']      NaN   tt6406976         6.4       368.0
# 3177               ['US']      NaN   tt8075260         6.1     22277.0
# 3274               ['US']      NaN   tt8328716         3.7      9281.0
# 5308               ['ES']      NaN  tt11924738         5.3      1931.0
# 5541               ['IN']      NaN         NaN         NaN         NaN
# 857                ['US']      6.0   tt3398228         8.8    148127.0
# 2944               ['IN']      NaN   tt8581230         2.2       483.0
# 5548               ['IN']      NaN  tt10152736         5.9     30621.0
#
#       tmdb_popularity  tmdb_score
# 2976            4.901         7.8
# 1425            9.634         5.9
# 2907            1.549         6.2
# 3177           14.238         6.4
# 3274           29.955         4.9
# 5308              NaN         NaN
# 5541            4.709         6.3
# 857            92.956         8.6
# 2944            3.448         7.0
# 5548            2.301         5.0

# %% [markdown]
# 先看结构性问题，可以发现在genres、production_countries两列中，存在含有多个值的单元格，下面对其进行处理

# %%
cleaned_titles = titles.copy()

# %% [markdown]
# 由于genres一列的数据类型是object，需要先将其转换成列表

# %%
cleaned_titles["genres"] = cleaned_titles["genres"].apply(lambda x: eval(x))
cleaned_titles["genres"][0]
# Out:
# ['documentation']

# %% [markdown]
# 使用explode方法，拆分行

# %%
cleaned_titles = cleaned_titles.explode("genres")

# %%
cleaned_titles.sample(10)
# Out:
#             id                                     title   type  \
# 1857   ts82560                              Dark Tourist   SHOW
# 1219   ts52838                                        3%   SHOW
# 366    ts30288                Mobile Suit Gundam Unicorn   SHOW
# 152   tm117488                       The Next Karate Kid  MOVIE
# 353   tm103095                                  Ip Man 2  MOVIE
# 1244    ts3844                                  Aquarius   SHOW
# 280    tm29737                                     Rambo  MOVIE
# 1763   ts58155                               Alias Grace   SHOW
# 738   tm177044  Naruto Shippuden the Movie: Blood Prison  MOVIE
# 2562   ts83204                        Million Pound Menu   SHOW
#
#                                             description  release_year  \
# 1857  The definition of "tourism" is redefined as Ne...          2018
# 1219  In a future where the elite inhabit an island ...          2016
# 366   The series begins in U.C. 0001, at the very be...          2010
# 152   Mr. Miyagi decides to take Julie, a troubled t...          1994
# 353   Having defeated the best fighters of the Imper...          2010
# 1244  In the late 1960s, a Los Angeles police sergea...          2015
# 280   When governments fail to act on behalf of capt...          2008
# 1763  Based on the true story of Grace Marks, a hous...          2017
# 738   After his capture for attempted assassination ...          2011
# 2562  Participants try to convince a jury that their...          2018
#
#      age_certification  runtime         genres production_countries  seasons  \
# 1857             TV-MA       41  documentation               ['NZ']      1.0
# 1219             TV-MA       46         action               ['BR']      4.0
# 366              TV-14       36            war               ['JP']      2.0
# 152                 PG      107        romance               ['US']      NaN
# 353                  R      108        history         ['HK', 'CN']      NaN
# 1244             TV-14       43          crime               ['US']      2.0
# 280                  R       92       thriller         ['DE', 'US']      NaN
# 1763             TV-MA       44        history               ['CA']      1.0
# 738              PG-13      108      animation               ['JP']      NaN
# 2562               NaN       60        reality               ['GB']      2.0
#
#         imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1857  tt8725166         7.5      7233.0            6.668       6.500
# 1219  tt4922804         7.3     25452.0           29.033       7.200
# 366   tt1587790         7.8      1291.0           10.936       7.900
# 152   tt0110657         4.5     30422.0           20.185       5.318
# 353   tt1386932         7.5    104500.0            4.516       7.500
# 1244  tt3768572         7.0     12279.0           13.111       6.800
# 280   tt0462499         7.0    230333.0           72.224       6.600
# 1763  tt1034007         7.7     32177.0           13.586       7.300
# 738   tt1999167         7.1      5104.0          184.852       7.200
# 2562  tt8488494         6.6       565.0            4.744       6.200

# %% [markdown]
# 同理，对production_countries一列进行相同的操作

# %%
cleaned_titles["production_countries"] = cleaned_titles["production_countries"].apply(lambda x: eval(x))

# %%
cleaned_titles = cleaned_titles.explode("production_countries")
cleaned_titles.sample(10)
# Out:
#              id                                              title   type  \
# 1023   tm175954                          Aziz Ansari: Buried Alive  MOVIE
# 1581   tm235227                            Bill Hicks: Reflections  MOVIE
# 1963   tm211554                                     Beyond Skyline  MOVIE
# 693    tm176507                                        Jackass 3.5  MOVIE
# 2748   tm279017  Michael Bolton's Big, Sexy Valentine's Day Spe...  MOVIE
# 3931    ts90280                                             Yankee   SHOW
# 5843  tm1097142                                           My Bride  MOVIE
# 845    tm176864                                               Rush  MOVIE
# 4768   ts222522                                           Spriggan   SHOW
# 420     tm33981                                    Bon Cop Bad Cop  MOVIE
#
#                                             description  release_year  \
# 1023  Standup comedian Aziz Ansari ("Parks and Recre...          2013
# 1581  Comedy Dynamics sits down with Bill Hicks’ bro...          2015
# 1963  Detective Mark Corley storms his way onto an a...          2017
# 693   Johnny Knoxville of 'Jackass' releases unused ...          2011
# 2748  After Santa tells Michael Bolton that he needs...          2017
# 3931  On the run from the police, an Arizona man cro...          2019
# 5843  The story follows a young man and woman who go...          2021
# 845   A biographical drama centered on the rivalry b...          2013
# 4768  An ancient civilization's relics on Earth hold...          2022
# 420   When the body of the executive of hockey Benoi...          2006
#
#      age_certification  runtime         genres production_countries  seasons  \
# 1023               NaN       79  documentation                   US      NaN
# 1581               NaN       34  documentation                   US      NaN
# 1963                 R      105         action                   SG      NaN
# 693                NaN       85  documentation                   US      NaN
# 2748               NaN       54          music                   US      NaN
# 3931             TV-MA       38          crime                   MX      1.0
# 5843               NaN       93         comedy                   EG      NaN
# 845                  R      123          sport                   DE      NaN
# 4768             TV-MA       46       thriller                   JP      1.0
# 420              PG-13      116          scifi                   CA      NaN
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1023   tt2836450         7.2      3998.0            5.417         7.0
# 1581         NaN         NaN         NaN            2.465         6.7
# 1963   tt6856700         5.3     21834.0           10.535         5.2
# 693          NaN         NaN         NaN           19.565         6.3
# 2748   tt6343706         6.8      2126.0            4.616         6.4
# 3931   tt9046782         5.8       701.0            8.380         6.6
# 5843  tt14216488         5.0       327.0            2.545         5.3
# 845    tt1979320         8.1    471586.0           29.759         7.7
# 4768  tt10011306         7.0       664.0           16.710         6.9
# 420    tt0443521         6.5        61.0            7.956         6.4

# %% [markdown]
# 结构性问题处理完毕，下面看是否有内容性问题

# %%
cleaned_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17818 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17818 non-null  object
#  1   title                 17817 non-null  object
#  2   type                  17818 non-null  object
#  3   description           17790 non-null  object
#  4   release_year          17818 non-null  int64
#  5   age_certification     10889 non-null  object
#  6   runtime               17818 non-null  int64
#  7   genres                17755 non-null  object
#  8   production_countries  17439 non-null  object
#  9   seasons               6224 non-null   float64
#  10  imdb_id               17116 non-null  object
#  11  imdb_score            16976 non-null  float64
#  12  imdb_votes            16945 non-null  float64
#  13  tmdb_popularity       17663 non-null  float64
#  14  tmdb_score            17241 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# 将release_year转换成datetime

# %%
cleaned_titles["release_year"] = pd.to_datetime(cleaned_titles["release_year"], format='%Y')
cleaned_titles["release_year"]
# Out:
# 0      1945-01-01
# 1      1976-01-01
# 1      1976-01-01
# 2      1972-01-01
# 2      1972-01-01
#           ...
# 5847   2021-01-01
# 5848   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# Name: release_year, Length: 17818, dtype: datetime64[ns]

# %% [markdown]
# 不难发现，有许多列存在缺失数据的情况，但是genres和imdb_score缺失会影响到我们的分析过程

# %%
cleaned_titles[cleaned_titles["genres"].isnull()]
# Out:
#              id                                      title   type  \
# 212    tm255589                              One Last Shot  MOVIE
# 619    tm341561                    Like Twenty Impossibles  MOVIE
# 632     ts86241               Le Robe De Mariage Des Cieux   SHOW
# 636    tm404676                       To and from New York  MOVIE
# 637     tm89054                        Osuofia in London 2  MOVIE
# ...         ...                                        ...    ...
# 5799  tm1040959                 The Circle: The Afterparty  MOVIE
# 5802   ts302434    Plastic Cup Boyz: Laughing My Mask Off!   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description release_year  \
# 212   In this low-budget short film, two best buddie...   1998-01-01
# 619   Occupied Palestine: A serene landscape now poc...   2003-01-01
# 632   It was with much difficulty that Ai Qing was a...   2004-01-01
# 636   While covering a story in New York City, a Sea...   2006-01-01
# 637   Osuofia return to his Nigerian village with a ...   2004-01-01
# ...                                                 ...          ...
# 5799  Stars of The Circle drop by to discuss Season ...   2021-01-01
# 5802  Comedy collective The Plastic Cup Boyz pour ou...   2021-01-01
# 5840  In 14th-century Mali, an ambitious young royal...   2022-01-01
# 5844  The stars of "Bling Empire" discuss the show's...   2021-01-01
# 5848  Jamie Foxx, David Alan Grier and more from the...   2021-01-01
#
#      age_certification  runtime genres production_countries  seasons imdb_id  \
# 212                NaN       30    NaN                  NaN      NaN     NaN
# 619                NaN       16    NaN                   PS      NaN     NaN
# 632              TV-MA       63    NaN                  NaN      1.0     NaN
# 636                NaN       82    NaN                   US      NaN     NaN
# 637                NaN       72    NaN                   XX      NaN     NaN
# ...                ...      ...    ...                  ...      ...     ...
# 5799               NaN       35    NaN                   US      NaN     NaN
# 5802               NaN       33    NaN                  NaN      1.0     NaN
# 5840               NaN       26    NaN                  NaN      NaN     NaN
# 5844               NaN       35    NaN                   US      NaN     NaN
# 5848             PG-13       37    NaN                   US      NaN     NaN
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 212          NaN         NaN            1.890         5.2
# 619          NaN         NaN            0.812         6.5
# 632          NaN         NaN            0.600         NaN
# 636          NaN         NaN            1.401         5.8
# 637          NaN         NaN            1.091         NaN
# ...          ...         ...              ...         ...
# 5799         NaN         NaN            1.882        10.0
# 5802         NaN         NaN            0.683         NaN
# 5840         NaN         NaN            1.179         7.0
# 5844         NaN         NaN              NaN         NaN
# 5848         NaN         NaN            1.296        10.0
#
# [63 rows x 15 columns]

# %%
cleaned_titles[(cleaned_titles["genres"].isnull()) & (cleaned_titles["genres"].notnull())]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# 可以看见，genres一项缺失的，其imdb_score也缺失

# %%
cleaned_titles[cleaned_titles["imdb_score"].isnull()]
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 75     tm132164                       Bill Hicks: Sane Man  MOVIE
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# ...         ...                                        ...    ...
# 5810  tm1225897                                 Social Man  MOVIE
# 5833   ts307884                                 HQ Barbers   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description release_year  \
# 0     This collection includes 12 World War II-era p...   1945-01-01
# 75    Sane Man was filmed before Bill recorded ‘Dang...   1989-01-01
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...   1991-01-01
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...   1991-01-01
# 145   “Hajimete no Otsukai” (First Errand) is a Japa...   1991-01-01
# ...                                                 ...          ...
# 5810  Two competitive social media Influencers go he...   2021-01-01
# 5833  When a family run barber shop in the heart of ...   2021-01-01
# 5840  In 14th-century Mali, an ambitious young royal...   2022-01-01
# 5844  The stars of "Bling Empire" discuss the show's...   2021-01-01
# 5848  Jamie Foxx, David Alan Grier and more from the...   2021-01-01
#
#      age_certification  runtime         genres production_countries  seasons  \
# 0                TV-MA       51  documentation                   US      1.0
# 75                   R       80         comedy                   US      NaN
# 145               TV-G       18  documentation                   JP     12.0
# 145               TV-G       18         family                   JP     12.0
# 145               TV-G       18        reality                   JP     12.0
# ...                ...      ...            ...                  ...      ...
# 5810               NaN       96          drama                  NaN      NaN
# 5833             TV-14       24         comedy                   NG      1.0
# 5840               NaN       26            NaN                  NaN      NaN
# 5844               NaN       35            NaN                   US      NaN
# 5848             PG-13       37            NaN                   US      NaN
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0            NaN         NaN         NaN            0.600         NaN
# 75           NaN         NaN         NaN            3.377         7.5
# 145          NaN         NaN         NaN            7.730         7.8
# 145          NaN         NaN         NaN            7.730         7.8
# 145          NaN         NaN         NaN            7.730         7.8
# ...          ...         ...         ...              ...         ...
# 5810  tt20198164         NaN         NaN              NaN         NaN
# 5833         NaN         NaN         NaN            0.840         NaN
# 5840         NaN         NaN         NaN            1.179         7.0
# 5844         NaN         NaN         NaN              NaN         NaN
# 5848         NaN         NaN         NaN            1.296        10.0
#
# [842 rows x 15 columns]

# %%
cleaned_titles.dropna(subset = ["genres"], axis = 0, inplace = True)
cleaned_titles[cleaned_titles["genres"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
cleaned_titles.dropna(subset = ["imdb_score"], axis = 0, inplace = True)

# %%
cleaned_titles[cleaned_titles["imdb_score"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# 接下来查看是否有不一致数据

# %%
cleaned_titles.value_counts("genres")
# Out:
# genres
# drama            3357
# comedy           2419
# thriller         1446
# action           1339
# romance          1080
# crime            1066
# documentation     981
# family            769
# animation         732
# fantasy           727
# european          679
# scifi             647
# horror            438
# history           336
# music             266
# reality           226
# war               221
# sport             188
# western            53
# Name: count, dtype: int64

# %%
cleaned_titles.value_counts("production_countries")
# Out:
# production_countries
# US    5648
# IN    1610
# GB    1068
# JP    1046
# FR     720
#       ...
# AF       1
# GT       1
# GE       1
# FO       1
# CU       1
# Name: count, Length: 108, dtype: int64

# %%
with pd.option_context('display.max_rows', None):
    print(cleaned_titles['production_countries'].value_counts())
# Out:
# production_countries
# US         5648
# IN         1610
# GB         1068
# JP         1046
# FR          720
# KR          637
# ES          637
# CA          608
# DE          383
# CN          295
# MX          264
# IT          224
# BR          221
# AU          217
# TR          195
# PH          192
# AR          150
# ID          149
# BE          148
# TW          133
# NG          131
# PL          126
# ZA          103
# NL          102
# HK          102
# CO           94
# EG           93
# DK           89
# TH           87
# SE           81
# LB           70
# NO           68
# AE           52
# IE           49
# SG           47
# XX           43
# IL           42
# RU           41
# CL           35
# CH           33
# PS           32
# BG           31
# MY           30
# SA           28
# AT           28
# IS           28
# LU           27
# NZ           27
# PE           26
# RO           25
# QA           24
# CZ           22
# JO           19
# FI           18
# HU           18
# UY           15
# MA           15
# PT           14
# KH           10
# KW           10
# PR            9
# PK            9
# MT            8
# UA            8
# VN            8
# LT            7
# IR            7
# SU            7
# CD            7
# TN            7
# SN            6
# AL            6
# KE            6
# GH            6
# IQ            5
# MU            5
# CY            5
# KN            4
# GR            4
# IO            4
# SY            4
# MC            4
# TZ            4
# GL            3
# HR            3
# AO            3
# BD            3
# CM            3
# PY            3
# BS            3
# DZ            3
# ZW            2
# KG            2
# BT            2
# VE            2
# RS            2
# MW            2
# VA            2
# BY            2
# BF            2
# GE            1
# AF            1
# Lebanon       1
# GT            1
# CU            1
# LK            1
# NP            1
# FO            1
# Name: count, dtype: int64

# %% [markdown]
# "LB"和"Lebanon"指代同一个国家

# %%
cleaned_titles.replace({"Lebanon" : "LB"}, inplace = True)
with pd.option_context('display.max_rows', None):
    print(cleaned_titles.explode('production_countries')['production_countries'].value_counts())
# Out:
# production_countries
# US    5648
# IN    1610
# GB    1068
# JP    1046
# FR     720
# KR     637
# ES     637
# CA     608
# DE     383
# CN     295
# MX     264
# IT     224
# BR     221
# AU     217
# TR     195
# PH     192
# AR     150
# ID     149
# BE     148
# TW     133
# NG     131
# PL     126
# ZA     103
# HK     102
# NL     102
# CO      94
# EG      93
# DK      89
# TH      87
# SE      81
# LB      71
# NO      68
# AE      52
# IE      49
# SG      47
# XX      43
# IL      42
# RU      41
# CL      35
# CH      33
# PS      32
# BG      31
# MY      30
# AT      28
# SA      28
# IS      28
# LU      27
# NZ      27
# PE      26
# RO      25
# QA      24
# CZ      22
# JO      19
# FI      18
# HU      18
# UY      15
# MA      15
# PT      14
# KW      10
# KH      10
# PK       9
# PR       9
# UA       8
# MT       8
# VN       8
# LT       7
# IR       7
# CD       7
# SU       7
# TN       7
# SN       6
# AL       6
# KE       6
# GH       6
# IQ       5
# MU       5
# CY       5
# KN       4
# GR       4
# IO       4
# SY       4
# TZ       4
# MC       4
# GL       3
# CM       3
# AO       3
# BS       3
# HR       3
# BD       3
# PY       3
# DZ       3
# KG       2
# BT       2
# BF       2
# MW       2
# RS       2
# VE       2
# ZW       2
# VA       2
# BY       2
# NP       1
# GE       1
# AF       1
# LK       1
# GT       1
# CU       1
# FO       1
# Name: count, dtype: int64

# %% [markdown]
# # 整理数据

# %%
credits_with_titles = pd.merge(cleaned_credits, cleaned_titles, on="id", how="inner")

# %%
credits_with_titles.head()
# Out:
#   person_id       id            name      character   role        title  \
# 0      3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 1      3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 2     14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 3     14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 4      7064  tm84618   Albert Brooks            Tom  ACTOR  Taxi Driver
#
#     type                                        description release_year  \
# 0  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 2  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 3  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 4  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
#
#   age_certification  runtime genres production_countries  seasons    imdb_id  \
# 0                 R      114  drama                   US      NaN  tt0075314
# 1                 R      114  crime                   US      NaN  tt0075314
# 2                 R      114  drama                   US      NaN  tt0075314
# 3                 R      114  crime                   US      NaN  tt0075314
# 4                 R      114  drama                   US      NaN  tt0075314
#
#    imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0         8.2    808582.0           40.965       8.179
# 1         8.2    808582.0           40.965       8.179
# 2         8.2    808582.0           40.965       8.179
# 3         8.2    808582.0           40.965       8.179
# 4         8.2    808582.0           40.965       8.179

# %% [markdown]
# 只对演员进行分析

# %%
actor_with_titles = credits_with_titles.query('role == "ACTOR"')

# %%
actor_with_titles.head()
# Out:
#   person_id       id            name      character   role        title  \
# 0      3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 1      3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 2     14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 3     14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 4      7064  tm84618   Albert Brooks            Tom  ACTOR  Taxi Driver
#
#     type                                        description release_year  \
# 0  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 2  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 3  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 4  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
#
#   age_certification  runtime genres production_countries  seasons    imdb_id  \
# 0                 R      114  drama                   US      NaN  tt0075314
# 1                 R      114  crime                   US      NaN  tt0075314
# 2                 R      114  drama                   US      NaN  tt0075314
# 3                 R      114  crime                   US      NaN  tt0075314
# 4                 R      114  drama                   US      NaN  tt0075314
#
#    imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0         8.2    808582.0           40.965       8.179
# 1         8.2    808582.0           40.965       8.179
# 2         8.2    808582.0           40.965       8.179
# 3         8.2    808582.0           40.965       8.179
# 4         8.2    808582.0           40.965       8.179

# %%
genres_person_id_imdb_scores = actor_with_titles.groupby(["genres","person_id"])["imdb_score"].mean().reset_index()
genres_person_id_imdb_scores
# Out:
#          genres person_id  imdb_score
# 0        action      1000    6.866667
# 1        action    100007    7.000000
# 2        action    100013    6.400000
# 3        action    100019    6.500000
# 4        action    100020    6.500000
# ...         ...       ...         ...
# 168876  western    993735    6.500000
# 168877  western    998673    7.300000
# 168878  western    998674    7.300000
# 168879  western    998675    7.300000
# 168880  western     99940    4.000000
#
# [168881 rows x 3 columns]

# %%
genres_max_imdb_score = genres_person_id_imdb_scores.groupby("genres")["imdb_score"].max()
genres_max_imdb_score
# Out:
# genres
# action           9.3
# animation        9.3
# comedy           9.2
# crime            9.5
# documentation    9.1
# drama            9.5
# european         8.9
# family           9.3
# fantasy          9.3
# history          9.1
# horror           9.0
# music            8.8
# reality          8.9
# romance          9.2
# scifi            9.3
# sport            9.1
# thriller         9.5
# war              8.8
# western          8.9
# Name: imdb_score, dtype: float64

# %%
genres_max_imdb_score_person_id = pd.merge(genres_person_id_imdb_scores, genres_max_imdb_score, on = ["imdb_score","genres"], how = "inner")
genres_max_imdb_score_person_id
# Out:
#       genres person_id  imdb_score
# 0     action     12790         9.3
# 1     action      1303         9.3
# 2     action     21033         9.3
# 3     action    336830         9.3
# 4     action     86591         9.3
# ..       ...       ...         ...
# 131      war    826547         8.8
# 132  western     22311         8.9
# 133  western     28166         8.9
# 134  western     28180         8.9
# 135  western     93017         8.9
#
# [136 rows x 3 columns]

# %%
actor_name_person_id = actor_with_titles[["person_id","name"]].drop_duplicates()
genres_max_imdb_score_person_id_name = pd.merge(genres_max_imdb_score_person_id, actor_name_person_id, on = "person_id",
                                                how = "left")
genres_max_imdb_score_person_id_name
# Out:
#       genres person_id  imdb_score                name
# 0     action     12790         9.3         Olivia Hack
# 1     action      1303         9.3       Jessie Flower
# 2     action     21033         9.3          Zach Tyler
# 3     action    336830         9.3     André Sogliuzzo
# 4     action     86591         9.3       Cricket Leigh
# ..       ...       ...         ...                 ...
# 131      war    826547         8.8         Yuto Uemura
# 132  western     22311         8.9     Koichi Yamadera
# 133  western     28166         8.9  Megumi Hayashibara
# 134  western     28180         8.9      Unsho Ishizuka
# 135  western     93017         8.9            Aoi Tada
#
# [136 rows x 4 columns]
